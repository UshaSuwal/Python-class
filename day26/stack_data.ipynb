# %%
import pandas as pd
df=pd.read_csv("survey_results_public.csv")
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail(10)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88873       88062        NaN       No
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88873                                              Never
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# ...

# %%
df.iloc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df.iloc[[0,1,2],[0,1]]
# Out:
#    Respondent                                         MainBranch
# 0           1             I am a student who is learning to code
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...

# %%
df.iloc[[0,1,2],[0,1,2]]
# Out:
#    Respondent                                         MainBranch Hobbyist
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes

# %%
df.iloc[0:10,0:10]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
# question no. 3
# this should be run in start. It will take 10 rows and 5 columns from huge dataset.
# pd.set_option('display.max_rows',10)
# pd.set_option('display.max_columns',5)

# %%
df.loc[[0,1,2],["Respondent","Hobbyist","Country"]]
# Out:
#    Respondent Hobbyist                 Country
# 0           1      Yes          United Kingdom
# 1           2       No  Bosnia and Herzegovina
# 2           3      Yes                Thailand

# %%
df.loc[0:10,"Respondent":"UndergradMajor"]
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 0            1             I am a student who is learning to code      Yes
# 1            2             I am a student who is learning to code       No
# 2            3  I am not primarily a developer, but I write co...      Yes
# 3            4                     I am a developer by profession       No
# 4            5                     I am a developer by profession      Yes
# 5            6  I am not primarily a developer, but I write co...      Yes
# 6            7                     I am a developer by profession       No
# 7            8                        I code primarily as a hobby      Yes
# 8            9                     I am a developer by profession      Yes
# 9           10                     I am a developer by profession      Yes
# 10          11                        I code primarily as a hobby      Yes
#
#                    OpenSourcer  \
# 0                        Never
# ...

# %%
df.set_index("Respondent",inplace=True)

# %%
df.sort_index(ascending=False)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 88883                          I am a developer by profession      Yes
# 88882                          I am a developer by profession      Yes
# 88881                          I am a developer by profession      Yes
# 88880       I am not primarily a developer, but I write co...      Yes
# 88879                          I am a developer by profession      Yes
# ...                                                       ...      ...
# 5                              I am a developer by profession      Yes
# 4                              I am a developer by profession       No
# 3           I am not primarily a developer, but I write co...      Yes
# 2                      I am a student who is learning to code       No
# 1                      I am a student who is learning to code      Yes
#
#                            OpenSourcer  \
# Respondent
# 88883       Once a month or more often
# ...

# %%
schema_df=pd.read_csv("survey_results_schema.csv",index_col="Column")
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc[["MainBranch","Hobbyist","FizzBuzz","MgrIdiot"],"QuestionText"]
# Out:
# Column
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# FizzBuzz      Have you ever been asked to solve FizzBuzz in ...
# MgrIdiot      How confident are you that your manager knows ...
# Name: QuestionText, dtype: object

# %%
filt=df["Age"]>40
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country Student  \
# Respondent
# 7           42.0         Ukraine      No
# 22          47.0   United States      No
# 38          44.0  Czech Republic      No
# 39          42.0   United States      No
# 44          43.0         Germany      No
# ...          ...             ...     ...
# 82717       44.0   United States      No
# 83786       57.0         Germany      No
# 85961       45.0  United Kingdom      No
# 86566       74.0     Switzerland      No
# 87352       59.0     Netherlands      No
#
#                                            LanguageWorkedWith
# Respondent
# 7                                         HTML/CSS;JavaScript
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 38                                 C#;HTML/CSS;JavaScript;SQL
# 39                               C#;JavaScript;SQL;TypeScript
# 44          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# ...                                                       ...
# ...

# %%
filt=(df["Country"]=="India") | (df["Country"]=="United Kingdom") | (df["Country"]=="Canada") | (df["Country"]=="Thailand")
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country         Student  \
# Respondent
# 1           14.0  United Kingdom              No
# 3           28.0        Thailand              No
# 6           28.0          Canada              No
# 8           24.0           India             NaN
# 10           NaN           India              No
# ...          ...             ...             ...
# 84539       23.0  United Kingdom  Yes, full-time
# 85182        NaN          Canada             NaN
# 85961       45.0  United Kingdom              No
# 86012       24.0           India              No
# 88377        NaN          Canada              No
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 3                                                    HTML/CSS
# 6                                                  Java;R;SQL
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...

# %%
# Another way
Countries=["India","United Kingdom","Thailand","Canada"]
filt=df["Country"].isin (Countries)
df.loc[filt,["Age","Country","Student","LanguageWorkedWith"]]
# Out:
#              Age         Country         Student  \
# Respondent
# 1           14.0  United Kingdom              No
# 3           28.0        Thailand              No
# 6           28.0          Canada              No
# 8           24.0           India             NaN
# 10           NaN           India              No
# ...          ...             ...             ...
# 84539       23.0  United Kingdom  Yes, full-time
# 85182        NaN          Canada             NaN
# 85961       45.0  United Kingdom              No
# 86012       24.0           India              No
# 88377        NaN          Canada              No
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 3                                                    HTML/CSS
# 6                                                  Java;R;SQL
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...

# %%
Countries=["India","United Kingdom","Thailand","Canada"]
filt=(df["Country"].isin (Countries)) & df["LanguageWorkedWith"].str.contains("Python")
df.loc[filt,["Country","Student","LanguageWorkedWith"]]
# Out:
#                    Country         Student  \
# Respondent
# 1           United Kingdom              No
# 8                    India             NaN
# 10                   India              No
# 12                  Canada  Yes, full-time
# 21                  Canada             NaN
# ...                    ...             ...
# 79798       United Kingdom  Yes, full-time
# 82007               Canada             NaN
# 82789       United Kingdom              No
# 84299                India  Yes, full-time
# 84539       United Kingdom  Yes, full-time
#
#                                            LanguageWorkedWith
# Respondent
# 1                             HTML/CSS;Java;JavaScript;Python
# 8           Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 10                              C#;Go;JavaScript;Python;R;SQL
# 12           Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 21          Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# ...
